# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	#re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			#line = normalize('NFD', line).encode('ascii', 'ignore')
			#line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			#line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			#line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
		#	line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'nds.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-LowSaxon.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-LowSaxon.pkl
# [Run] => [Loop]
# [Hello] => [Moin]
# [Cheers] => [Proost]
# [I know] => [Ik weet]
# [Thanks] => [Bedankt]
# [Go away] => [Gah weg]
# [Im fat] => [Ik bün fett]
# [Shut up] => [Holl dat Muul]
# [Shut up] => [Holl den Sabbel]
# [Shut up] => [Holl de Snuut]
# [Wash up] => [Wasch di dat Gesicht]
# [Welcome] => [Willkamen]
# [Have fun] => [Veel Spaaß]
# [I forgot] => [Dat heff ik vergeten]
# [Im back] => [Ik bün dor wedder]
# [Im busy] => [Ik heff to doon]
# [Im cold] => [Mi is koold]
# [Im game] => [Ik maak mit]
# [Trust me] => [Vertro mi]
# [Come here] => [Kaam her]
# [Hes fast] => [He is gau]
# [I am cold] => [Mi is koold]
# [I mean it] => [Ik meen dat ook so]
# [Im a man] => [Ik bün en Mann]
# [Im drunk] => [Ik bün duun]
# [Im tired] => [Ik bün mööd]
# [Its cold] => [Dat is koold]
# [Its late] => [Dat is laat]
# [Let me go] => [Laat mi gahn]
# [Let me in] => [Laat mi rin]
# [Look back] => [Kiek achter di]
# [Sign here] => [Ünnerschriev hier]
# [Thank you] => [Bedankt]
# [Who is he] => [’Keen is he]
# [Am I wrong] => [Heff ik nich recht]
# [Can I help] => [Kann ik helpen]
# [Choose one] => [Söök een ut]
# [He laughed] => [He lach]
# [Hello Tom] => [Hallo Tom]
# [I am a boy] => [Ik bün en Jung]
# [I am a man] => [Ik bün en Mann]
# [I felt bad] => [Ik heff mi slecht föhlt]
# [I felt ill] => [Ik heff mi krank föhlt]
# [I know him] => [Ik kenn em]
# [I like tea] => [Ik mag Tee]
# [I need you] => [Ik bruuk di]
# [I think so] => [Dat dücht mi so]
# [I want you] => [Ik will di]
# [Im hungry] => [Ik bün hungerig]
# [Ignore him] => [Acht nich op em]
# [Is this it] => [Dit hier]
# [Is this it] => [Disse hier]
# [Just do it] => [Do dat doch]
# [Let me die] => [Laat mi starven]
# [No comment] => [Dor segg ik nix to]
# [Time flies] => [De Tied flüggt]
# [Where am I] => [Woneem bün ik]
# [Wood burns] => [Holt brennt]
# [Can we talk] => [Köönt wi snacken]
# [Can we talk] => [Köönt wi küern]
# [Can we talk] => [Köönt wi praten]
# [Cook for me] => [Kaak för mi]
# [Dont leave] => [Gah nich weg]
# [He can swim] => [He kann swemmen]
# [I am taller] => [Ik bün grötter]
# [I bought it] => [Ik heff dat köfft]
# [I cant fly] => [Ik kann nich flegen]
# [I feel cold] => [Mi is koold]
# [I heard you] => [Ik heff di höört]
# [I know that] => [Ik weet dat]
# [I like cats] => [Ik mag Katten]
# [I like fish] => [Ik mag geern Fisch]
# [I live here] => [Ik leev hier]
# [I need help] => [Ik bruuk Hülp]
# [I thank you] => [Ik dank di]
# [I trust you] => [Ik vertroo di]
# [I was tired] => [Ik weer mööd]
# [Im a baker] => [Ik bün Bäcker]
# [Im at home] => [Ik bün tohuus]
# [Is he right] => [Hett he recht]
# [Is it white] => [Is dat witt]
# [Is it yours] => [Is dat dien]
# [Is she gone] => [Is se weg]
# [It may rain] => [Villicht regent dat]
# [It may snow] => [Villicht sneet dat]
# [Many thanks] => [Velen Dank]
# [She bit him] => [Se hett em beten]
# [Whats love] => [Wat is Leevd]
# [Where is he] => [Woneem is he]
# [Whose is it] => [’Keen sien is dat]
# [You are mad] => [Du büst mallerig]
# [Are you dead] => [Büst du dood]
# [Bring him in] => [Bring em rin]
# [Do you smoke] => [Smöökst du]
# [Do you smoke] => [Smöökt ji]
# [Does it work] => [Klappt dat]
# [Good morning] => [Goden Morgen]
# [Happy Easter] => [Frohe Oostern]
# [He is a poet] => [He is en Dichter]
# [He is chubby] => [He is wat pummelig]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-LowSaxon.pkl')

# reduce dataset size
n_sentences = 3206
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:3000], dataset[206:]
# save
save_clean_data(dataset, 'english-LowSaxon-both.pkl')
save_clean_data(train, 'english-LowSaxon-train.pkl')
save_clean_data(test, 'english-LowSaxon-test.pkl')
# Out:
# Saved: english-LowSaxon-both.pkl
# Saved: english-LowSaxon-train.pkl
# Saved: english-LowSaxon-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-LowSaxon-both.pkl')
train = load_clean_sentences('english-LowSaxon-train.pkl')
test = load_clean_sentences('english-LowSaxon-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Low Saxon Vocabulary Size: %d' % ger_vocab_size)
print('Low Saxon  Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=400, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2539
# English Max Length: 38
# Low Saxon Vocabulary Size: 2725
# Low Saxon  Max Length: 40
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 40, 256)           697600
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 38, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 38, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 38, 2539)          652523
# =================================================================
# Total params: 2,400,747
# Trainable params: 2,400,747
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/400
# 47/47 - 58s - loss: 2.6796 - val_loss: 1.2016
#
# Epoch 00001: val_loss improved from inf to 1.20164, saving model to model.h5
# Epoch 2/400
# 47/47 - 51s - loss: 1.0926 - val_loss: 1.0393
#
# Epoch 00002: val_loss improved from 1.20164 to 1.03934, saving model to model.h5
# Epoch 3/400
# 47/47 - 51s - loss: 1.0222 - val_loss: 1.0020
#
# Epoch 00003: val_loss improved from 1.03934 to 1.00203, saving model to model.h5
# Epoch 4/400
# 47/47 - 51s - loss: 1.0071 - val_loss: 0.9836
#
# Epoch 00004: val_loss improved from 1.00203 to 0.98360, saving model to model.h5
# Epoch 5/400
# 47/47 - 51s - loss: 0.9903 - val_loss: 0.9654
#
# Epoch 00005: val_loss improved from 0.98360 to 0.96537, saving model to model.h5
# Epoch 6/400
# 47/47 - 51s - loss: 0.9679 - val_loss: 0.9508
#
# Epoch 00006: val_loss improved from 0.96537 to 0.95082, saving model to model.h5
# Epoch 7/400
# 47/47 - 51s - loss: 0.9537 - val_loss: 0.9387
#
# Epoch 00007: val_loss improved from 0.95082 to 0.93873, saving model to model.h5
# Epoch 8/400
# 47/47 - 51s - loss: 0.9381 - val_loss: 0.9233
#
# Epoch 00008: val_loss improved from 0.93873 to 0.92331, saving model to model.h5
# Epoch 9/400
# 47/47 - 51s - loss: 0.9204 - val_loss: 0.9112
#
# Epoch 00009: val_loss improved from 0.92331 to 0.91118, saving model to model.h5
# Epoch 10/400
# 47/47 - 51s - loss: 0.9067 - val_loss: 0.8959
#
# Epoch 00010: val_loss improved from 0.91118 to 0.89592, saving model to model.h5
# Epoch 11/400
# 47/47 - 51s - loss: 0.8959 - val_loss: 0.8869
#
# Epoch 00011: val_loss improved from 0.89592 to 0.88691, saving model to model.h5
# Epoch 12/400
# 47/47 - 51s - loss: 0.8848 - val_loss: 0.8763
#
# Epoch 00012: val_loss improved from 0.88691 to 0.87628, saving model to model.h5
# Epoch 13/400
# 47/47 - 51s - loss: 0.8747 - val_loss: 0.8686
#
# Epoch 00013: val_loss improved from 0.87628 to 0.86862, saving model to model.h5
# Epoch 14/400
# 47/47 - 51s - loss: 0.8662 - val_loss: 0.8626
#
# Epoch 00014: val_loss improved from 0.86862 to 0.86259, saving model to model.h5
# Epoch 15/400
# 47/47 - 51s - loss: 0.8606 - val_loss: 0.8595
#
# Epoch 00015: val_loss improved from 0.86259 to 0.85948, saving model to model.h5
# Epoch 16/400
# 47/47 - 51s - loss: 0.8562 - val_loss: 0.8539
#
# Epoch 00016: val_loss improved from 0.85948 to 0.85387, saving model to model.h5
# Epoch 17/400
# 47/47 - 51s - loss: 0.8535 - val_loss: 0.8504
#
# Epoch 00017: val_loss improved from 0.85387 to 0.85038, saving model to model.h5
# Epoch 18/400
# 47/47 - 51s - loss: 0.8485 - val_loss: 0.8510
#
# Epoch 00018: val_loss did not improve from 0.85038
# Epoch 19/400
# 47/47 - 51s - loss: 0.8438 - val_loss: 0.8417
#
# Epoch 00019: val_loss improved from 0.85038 to 0.84171, saving model to model.h5
# Epoch 20/400
# 47/47 - 51s - loss: 0.8380 - val_loss: 0.8380
#
# Epoch 00020: val_loss improved from 0.84171 to 0.83801, saving model to model.h5
# Epoch 21/400
# 47/47 - 51s - loss: 0.8334 - val_loss: 0.8340
#
# Epoch 00021: val_loss improved from 0.83801 to 0.83402, saving model to model.h5
# Epoch 22/400
# 47/47 - 51s - loss: 0.8306 - val_loss: 0.8312
#
# Epoch 00022: val_loss improved from 0.83402 to 0.83116, saving model to model.h5
# Epoch 23/400
# 47/47 - 51s - loss: 0.8269 - val_loss: 0.8283
#
# Epoch 00023: val_loss improved from 0.83116 to 0.82834, saving model to model.h5
# Epoch 24/400
# 47/47 - 51s - loss: 0.8235 - val_loss: 0.8256
#
# Epoch 00024: val_loss improved from 0.82834 to 0.82559, saving model to model.h5
# Epoch 25/400
# 47/47 - 51s - loss: 0.8208 - val_loss: 0.8216
#
# Epoch 00025: val_loss improved from 0.82559 to 0.82158, saving model to model.h5
# Epoch 26/400
# 47/47 - 51s - loss: 0.8166 - val_loss: 0.8179
#
# Epoch 00026: val_loss improved from 0.82158 to 0.81786, saving model to model.h5
# Epoch 27/400
# 47/47 - 51s - loss: 0.8117 - val_loss: 0.8151
#
# Epoch 00027: val_loss improved from 0.81786 to 0.81512, saving model to model.h5
# Epoch 28/400
# 47/47 - 51s - loss: 0.8078 - val_loss: 0.8113
#
# Epoch 00028: val_loss improved from 0.81512 to 0.81131, saving model to model.h5
# Epoch 29/400
# 47/47 - 51s - loss: 0.8040 - val_loss: 0.8063
#
# Epoch 00029: val_loss improved from 0.81131 to 0.80628, saving model to model.h5
# Epoch 30/400
# 47/47 - 51s - loss: 0.7988 - val_loss: 0.8014
#
# Epoch 00030: val_loss improved from 0.80628 to 0.80138, saving model to model.h5
# Epoch 31/400
# 47/47 - 51s - loss: 0.7944 - val_loss: 0.7983
#
# Epoch 00031: val_loss improved from 0.80138 to 0.79827, saving model to model.h5
# Epoch 32/400
# 47/47 - 51s - loss: 0.7899 - val_loss: 0.7975
#
# Epoch 00032: val_loss improved from 0.79827 to 0.79751, saving model to model.h5
# Epoch 33/400
# 47/47 - 51s - loss: 0.7857 - val_loss: 0.7910
#
# Epoch 00033: val_loss improved from 0.79751 to 0.79097, saving model to model.h5
# Epoch 34/400
# 47/47 - 51s - loss: 0.7803 - val_loss: 0.7829
#
# Epoch 00034: val_loss improved from 0.79097 to 0.78287, saving model to model.h5
# Epoch 35/400
# 47/47 - 51s - loss: 0.7730 - val_loss: 0.7786
#
# Epoch 00035: val_loss improved from 0.78287 to 0.77857, saving model to model.h5
# Epoch 36/400
# 47/47 - 51s - loss: 0.7671 - val_loss: 0.7711
#
# Epoch 00036: val_loss improved from 0.77857 to 0.77106, saving model to model.h5
# Epoch 37/400
# 47/47 - 51s - loss: 0.7618 - val_loss: 0.7653
#
# Epoch 00037: val_loss improved from 0.77106 to 0.76534, saving model to model.h5
# Epoch 38/400
# 47/47 - 51s - loss: 0.7554 - val_loss: 0.7580
#
# Epoch 00038: val_loss improved from 0.76534 to 0.75795, saving model to model.h5
# Epoch 39/400
# 47/47 - 51s - loss: 0.7499 - val_loss: 0.7609
#
# Epoch 00039: val_loss did not improve from 0.75795
# Epoch 40/400
# 47/47 - 51s - loss: 0.7441 - val_loss: 0.7459
#
# Epoch 00040: val_loss improved from 0.75795 to 0.74588, saving model to model.h5
# Epoch 41/400
# 47/47 - 51s - loss: 0.7337 - val_loss: 0.7399
#
# Epoch 00041: val_loss improved from 0.74588 to 0.73993, saving model to model.h5
# Epoch 42/400
# 47/47 - 51s - loss: 0.7264 - val_loss: 0.7306
#
# Epoch 00042: val_loss improved from 0.73993 to 0.73065, saving model to model.h5
# Epoch 43/400
# 47/47 - 51s - loss: 0.7157 - val_loss: 0.7196
#
# Epoch 00043: val_loss improved from 0.73065 to 0.71956, saving model to model.h5
# Epoch 44/400
# 47/47 - 51s - loss: 0.7048 - val_loss: 0.7096
#
# Epoch 00044: val_loss improved from 0.71956 to 0.70961, saving model to model.h5
# Epoch 45/400
# 47/47 - 51s - loss: 0.6952 - val_loss: 0.7000
#
# Epoch 00045: val_loss improved from 0.70961 to 0.69999, saving model to model.h5
# Epoch 46/400
# 47/47 - 51s - loss: 0.6856 - val_loss: 0.6941
#
# Epoch 00046: val_loss improved from 0.69999 to 0.69411, saving model to model.h5
# Epoch 47/400
# 47/47 - 51s - loss: 0.6751 - val_loss: 0.6817
#
# Epoch 00047: val_loss improved from 0.69411 to 0.68174, saving model to model.h5
# Epoch 48/400
# 47/47 - 51s - loss: 0.6652 - val_loss: 0.6707
#
# Epoch 00048: val_loss improved from 0.68174 to 0.67066, saving model to model.h5
# Epoch 49/400
# 47/47 - 51s - loss: 0.6541 - val_loss: 0.6607
#
# Epoch 00049: val_loss improved from 0.67066 to 0.66074, saving model to model.h5
# Epoch 50/400
# 47/47 - 51s - loss: 0.6429 - val_loss: 0.6489
#
# Epoch 00050: val_loss improved from 0.66074 to 0.64886, saving model to model.h5
# Epoch 51/400
# 47/47 - 51s - loss: 0.6317 - val_loss: 0.6414
#
# Epoch 00051: val_loss improved from 0.64886 to 0.64140, saving model to model.h5
# Epoch 52/400
# 47/47 - 51s - loss: 0.6245 - val_loss: 0.6300
#
# Epoch 00052: val_loss improved from 0.64140 to 0.63002, saving model to model.h5
# Epoch 53/400
# 47/47 - 51s - loss: 0.6102 - val_loss: 0.6157
#
# Epoch 00053: val_loss improved from 0.63002 to 0.61574, saving model to model.h5
# Epoch 54/400
# 47/47 - 51s - loss: 0.5954 - val_loss: 0.6029
#
# Epoch 00054: val_loss improved from 0.61574 to 0.60290, saving model to model.h5
# Epoch 55/400
# 47/47 - 51s - loss: 0.5861 - val_loss: 0.5920
#
# Epoch 00055: val_loss improved from 0.60290 to 0.59202, saving model to model.h5
# Epoch 56/400
# 47/47 - 51s - loss: 0.5743 - val_loss: 0.5809
#
# Epoch 00056: val_loss improved from 0.59202 to 0.58090, saving model to model.h5
# Epoch 57/400
# 47/47 - 51s - loss: 0.5623 - val_loss: 0.5656
#
# Epoch 00057: val_loss improved from 0.58090 to 0.56557, saving model to model.h5
# Epoch 58/400
# 47/47 - 50s - loss: 0.5480 - val_loss: 0.5588
#
# Epoch 00058: val_loss improved from 0.56557 to 0.55879, saving model to model.h5
# Epoch 59/400
# 47/47 - 51s - loss: 0.5344 - val_loss: 0.5527
#
# Epoch 00059: val_loss improved from 0.55879 to 0.55274, saving model to model.h5
# Epoch 60/400
# 47/47 - 51s - loss: 0.5218 - val_loss: 0.5291
#
# Epoch 00060: val_loss improved from 0.55274 to 0.52907, saving model to model.h5
# Epoch 61/400
# 47/47 - 51s - loss: 0.5087 - val_loss: 0.5192
#
# Epoch 00061: val_loss improved from 0.52907 to 0.51916, saving model to model.h5
# Epoch 62/400
# 47/47 - 51s - loss: 0.4968 - val_loss: 0.5098
#
# Epoch 00062: val_loss improved from 0.51916 to 0.50983, saving model to model.h5
# Epoch 63/400
# 47/47 - 51s - loss: 0.4841 - val_loss: 0.4987
#
# Epoch 00063: val_loss improved from 0.50983 to 0.49866, saving model to model.h5
# Epoch 64/400
# 47/47 - 51s - loss: 0.4744 - val_loss: 0.4901
#
# Epoch 00064: val_loss improved from 0.49866 to 0.49013, saving model to model.h5
# Epoch 65/400
# 47/47 - 51s - loss: 0.4660 - val_loss: 0.4803
#
# Epoch 00065: val_loss improved from 0.49013 to 0.48025, saving model to model.h5
# Epoch 66/400
# 47/47 - 51s - loss: 0.4547 - val_loss: 0.4666
#
# Epoch 00066: val_loss improved from 0.48025 to 0.46660, saving model to model.h5
# Epoch 67/400
# 47/47 - 51s - loss: 0.4418 - val_loss: 0.4590
#
# Epoch 00067: val_loss improved from 0.46660 to 0.45900, saving model to model.h5
# Epoch 68/400
# 47/47 - 51s - loss: 0.4281 - val_loss: 0.4449
#
# Epoch 00068: val_loss improved from 0.45900 to 0.44494, saving model to model.h5
# Epoch 69/400
# 47/47 - 51s - loss: 0.4162 - val_loss: 0.4347
#
# Epoch 00069: val_loss improved from 0.44494 to 0.43471, saving model to model.h5
# Epoch 70/400
# 47/47 - 51s - loss: 0.4059 - val_loss: 0.4245
#
# Epoch 00070: val_loss improved from 0.43471 to 0.42447, saving model to model.h5
# Epoch 71/400
# 47/47 - 51s - loss: 0.3966 - val_loss: 0.4191
#
# Epoch 00071: val_loss improved from 0.42447 to 0.41905, saving model to model.h5
# Epoch 72/400
# 47/47 - 51s - loss: 0.3867 - val_loss: 0.4072
#
# Epoch 00072: val_loss improved from 0.41905 to 0.40717, saving model to model.h5
# Epoch 73/400
# 47/47 - 51s - loss: 0.3764 - val_loss: 0.3980
#
# Epoch 00073: val_loss improved from 0.40717 to 0.39798, saving model to model.h5
# Epoch 74/400
# 47/47 - 51s - loss: 0.3654 - val_loss: 0.3930
#
# Epoch 00074: val_loss improved from 0.39798 to 0.39298, saving model to model.h5
# Epoch 75/400
# 47/47 - 51s - loss: 0.3613 - val_loss: 0.3897
#
# Epoch 00075: val_loss improved from 0.39298 to 0.38971, saving model to model.h5
# Epoch 76/400
# 47/47 - 51s - loss: 0.3532 - val_loss: 0.3776
#
# Epoch 00076: val_loss improved from 0.38971 to 0.37764, saving model to model.h5
# Epoch 77/400
# 47/47 - 51s - loss: 0.3437 - val_loss: 0.3656
#
# Epoch 00077: val_loss improved from 0.37764 to 0.36556, saving model to model.h5
# Epoch 78/400
# 47/47 - 51s - loss: 0.3329 - val_loss: 0.3579
#
# Epoch 00078: val_loss improved from 0.36556 to 0.35790, saving model to model.h5
# Epoch 79/400
# 47/47 - 51s - loss: 0.3231 - val_loss: 0.3513
#
# Epoch 00079: val_loss improved from 0.35790 to 0.35128, saving model to model.h5
# Epoch 80/400
# 47/47 - 50s - loss: 0.3116 - val_loss: 0.3403
#
# Epoch 00080: val_loss improved from 0.35128 to 0.34029, saving model to model.h5
# Epoch 81/400
# 47/47 - 51s - loss: 0.3018 - val_loss: 0.3321
#
# Epoch 00081: val_loss improved from 0.34029 to 0.33214, saving model to model.h5
# Epoch 82/400
# 47/47 - 50s - loss: 0.2942 - val_loss: 0.3281
#
# Epoch 00082: val_loss improved from 0.33214 to 0.32813, saving model to model.h5
# Epoch 83/400
# 47/47 - 51s - loss: 0.2876 - val_loss: 0.3207
#
# Epoch 00083: val_loss improved from 0.32813 to 0.32068, saving model to model.h5
# Epoch 84/400
# 47/47 - 51s - loss: 0.2790 - val_loss: 0.3125
#
# Epoch 00084: val_loss improved from 0.32068 to 0.31247, saving model to model.h5
# Epoch 85/400
# 47/47 - 51s - loss: 0.2738 - val_loss: 0.3120
#
# Epoch 00085: val_loss improved from 0.31247 to 0.31202, saving model to model.h5
# Epoch 86/400
# 47/47 - 51s - loss: 0.2729 - val_loss: 0.3062
#
# Epoch 00086: val_loss improved from 0.31202 to 0.30618, saving model to model.h5
# Epoch 87/400
# 47/47 - 51s - loss: 0.2640 - val_loss: 0.2966
#
# Epoch 00087: val_loss improved from 0.30618 to 0.29661, saving model to model.h5
# Epoch 88/400
# 47/47 - 51s - loss: 0.2557 - val_loss: 0.2986
#
# Epoch 00088: val_loss did not improve from 0.29661
# Epoch 89/400
# 47/47 - 51s - loss: 0.2481 - val_loss: 0.2825
#
# Epoch 00089: val_loss improved from 0.29661 to 0.28254, saving model to model.h5
# Epoch 90/400
# 47/47 - 51s - loss: 0.2372 - val_loss: 0.2744
#
# Epoch 00090: val_loss improved from 0.28254 to 0.27437, saving model to model.h5
# Epoch 91/400
# 47/47 - 51s - loss: 0.2276 - val_loss: 0.2659
#
# Epoch 00091: val_loss improved from 0.27437 to 0.26590, saving model to model.h5
# Epoch 92/400
# 47/47 - 51s - loss: 0.2215 - val_loss: 0.2622
#
# Epoch 00092: val_loss improved from 0.26590 to 0.26221, saving model to model.h5
# Epoch 93/400
# 47/47 - 51s - loss: 0.2173 - val_loss: 0.2592
#
# Epoch 00093: val_loss improved from 0.26221 to 0.25922, saving model to model.h5
# Epoch 94/400
# 47/47 - 51s - loss: 0.2121 - val_loss: 0.2531
#
# Epoch 00094: val_loss improved from 0.25922 to 0.25313, saving model to model.h5
# Epoch 95/400
# 47/47 - 50s - loss: 0.2075 - val_loss: 0.2488
#
# Epoch 00095: val_loss improved from 0.25313 to 0.24879, saving model to model.h5
# Epoch 96/400
# 47/47 - 51s - loss: 0.2006 - val_loss: 0.2450
#
# Epoch 00096: val_loss improved from 0.24879 to 0.24495, saving model to model.h5
# Epoch 97/400
# 47/47 - 51s - loss: 0.1951 - val_loss: 0.2397
#
# Epoch 00097: val_loss improved from 0.24495 to 0.23967, saving model to model.h5
# Epoch 98/400
# 47/47 - 51s - loss: 0.1924 - val_loss: 0.2375
#
# Epoch 00098: val_loss improved from 0.23967 to 0.23750, saving model to model.h5
# Epoch 99/400
# 47/47 - 50s - loss: 0.1868 - val_loss: 0.2308
#
# Epoch 00099: val_loss improved from 0.23750 to 0.23079, saving model to model.h5
# Epoch 100/400
# 47/47 - 51s - loss: 0.1789 - val_loss: 0.2250
#
# Epoch 00100: val_loss improved from 0.23079 to 0.22502, saving model to model.h5
# Epoch 101/400
# 47/47 - 50s - loss: 0.1722 - val_loss: 0.2189
#
# Epoch 00101: val_loss improved from 0.22502 to 0.21889, saving model to model.h5
# Epoch 102/400
# 47/47 - 51s - loss: 0.1669 - val_loss: 0.2144
#
# Epoch 00102: val_loss improved from 0.21889 to 0.21441, saving model to model.h5
# Epoch 103/400
# 47/47 - 51s - loss: 0.1726 - val_loss: 0.2170
#
# Epoch 00103: val_loss did not improve from 0.21441
# Epoch 104/400
# 47/47 - 51s - loss: 0.1630 - val_loss: 0.2101
#
# Epoch 00104: val_loss improved from 0.21441 to 0.21014, saving model to model.h5
# Epoch 105/400
# 47/47 - 51s - loss: 0.1565 - val_loss: 0.2079
#
# Epoch 00105: val_loss improved from 0.21014 to 0.20792, saving model to model.h5
# Epoch 106/400
# 47/47 - 51s - loss: 0.1497 - val_loss: 0.2006
#
# Epoch 00106: val_loss improved from 0.20792 to 0.20065, saving model to model.h5
# Epoch 107/400
# 47/47 - 51s - loss: 0.1456 - val_loss: 0.1957
#
# Epoch 00107: val_loss improved from 0.20065 to 0.19570, saving model to model.h5
# Epoch 108/400
# 47/47 - 51s - loss: 0.1399 - val_loss: 0.1921
#
# Epoch 00108: val_loss improved from 0.19570 to 0.19213, saving model to model.h5
# Epoch 109/400
# 47/47 - 51s - loss: 0.1357 - val_loss: 0.1866
#
# Epoch 00109: val_loss improved from 0.19213 to 0.18659, saving model to model.h5
# Epoch 110/400
# 47/47 - 51s - loss: 0.1316 - val_loss: 0.1849
#
# Epoch 00110: val_loss improved from 0.18659 to 0.18490, saving model to model.h5
# Epoch 111/400
# 47/47 - 51s - loss: 0.1271 - val_loss: 0.1791
#
# Epoch 00111: val_loss improved from 0.18490 to 0.17912, saving model to model.h5
# Epoch 112/400
# 47/47 - 51s - loss: 0.1232 - val_loss: 0.1792
#
# Epoch 00112: val_loss did not improve from 0.17912
# Epoch 113/400
# 47/47 - 51s - loss: 0.1212 - val_loss: 0.1774
#
# Epoch 00113: val_loss improved from 0.17912 to 0.17736, saving model to model.h5
# Epoch 114/400
# 47/47 - 51s - loss: 0.1182 - val_loss: 0.1732
#
# Epoch 00114: val_loss improved from 0.17736 to 0.17324, saving model to model.h5
# Epoch 115/400
# 47/47 - 51s - loss: 0.1153 - val_loss: 0.1730
#
# Epoch 00115: val_loss improved from 0.17324 to 0.17296, saving model to model.h5
# Epoch 116/400
# 47/47 - 51s - loss: 0.1136 - val_loss: 0.1688
#
# Epoch 00116: val_loss improved from 0.17296 to 0.16878, saving model to model.h5
# Epoch 117/400
# 47/47 - 51s - loss: 0.1104 - val_loss: 0.1665
#
# Epoch 00117: val_loss improved from 0.16878 to 0.16654, saving model to model.h5
# Epoch 118/400
# 47/47 - 51s - loss: 0.1065 - val_loss: 0.1619
#
# Epoch 00118: val_loss improved from 0.16654 to 0.16194, saving model to model.h5
# Epoch 119/400
# 47/47 - 51s - loss: 0.1015 - val_loss: 0.1586
#
# Epoch 00119: val_loss improved from 0.16194 to 0.15864, saving model to model.h5
# Epoch 120/400
# 47/47 - 50s - loss: 0.0978 - val_loss: 0.1553
#
# Epoch 00120: val_loss improved from 0.15864 to 0.15528, saving model to model.h5
# Epoch 121/400
# 47/47 - 51s - loss: 0.0973 - val_loss: 0.1569
#
# Epoch 00121: val_loss did not improve from 0.15528
# Epoch 122/400
# 47/47 - 51s - loss: 0.0957 - val_loss: 0.1545
#
# Epoch 00122: val_loss improved from 0.15528 to 0.15449, saving model to model.h5
# Epoch 123/400
# 47/47 - 51s - loss: 0.0933 - val_loss: 0.1521
#
# Epoch 00123: val_loss improved from 0.15449 to 0.15206, saving model to model.h5
# Epoch 124/400
# 47/47 - 51s - loss: 0.0899 - val_loss: 0.1508
#
# Epoch 00124: val_loss improved from 0.15206 to 0.15081, saving model to model.h5
# Epoch 125/400
# 47/47 - 51s - loss: 0.0878 - val_loss: 0.1481
#
# Epoch 00125: val_loss improved from 0.15081 to 0.14809, saving model to model.h5
# Epoch 126/400
# 47/47 - 51s - loss: 0.0843 - val_loss: 0.1433
#
# Epoch 00126: val_loss improved from 0.14809 to 0.14327, saving model to model.h5
# Epoch 127/400
# 47/47 - 51s - loss: 0.0798 - val_loss: 0.1413
#
# Epoch 00127: val_loss improved from 0.14327 to 0.14135, saving model to model.h5
# Epoch 128/400
# 47/47 - 51s - loss: 0.0771 - val_loss: 0.1379
#
# Epoch 00128: val_loss improved from 0.14135 to 0.13789, saving model to model.h5
# Epoch 129/400
# 47/47 - 51s - loss: 0.0737 - val_loss: 0.1356
#
# Epoch 00129: val_loss improved from 0.13789 to 0.13556, saving model to model.h5
# Epoch 130/400
# 47/47 - 51s - loss: 0.0728 - val_loss: 0.1371
#
# Epoch 00130: val_loss did not improve from 0.13556
# Epoch 131/400
# 47/47 - 51s - loss: 0.0721 - val_loss: 0.1359
#
# Epoch 00131: val_loss did not improve from 0.13556
# Epoch 132/400
# 47/47 - 51s - loss: 0.0723 - val_loss: 0.1359
#
# Epoch 00132: val_loss did not improve from 0.13556
# Epoch 133/400
# 47/47 - 51s - loss: 0.0726 - val_loss: 0.1349
#
# Epoch 00133: val_loss improved from 0.13556 to 0.13490, saving model to model.h5
# Epoch 134/400
# 47/47 - 51s - loss: 0.0702 - val_loss: 0.1367
#
# Epoch 00134: val_loss did not improve from 0.13490
# Epoch 135/400
# 47/47 - 51s - loss: 0.0687 - val_loss: 0.1314
#
# Epoch 00135: val_loss improved from 0.13490 to 0.13142, saving model to model.h5
# Epoch 136/400
# 47/47 - 51s - loss: 0.0635 - val_loss: 0.1287
#
# Epoch 00136: val_loss improved from 0.13142 to 0.12866, saving model to model.h5
# Epoch 137/400
# 47/47 - 50s - loss: 0.0621 - val_loss: 0.1264
#
# Epoch 00137: val_loss improved from 0.12866 to 0.12640, saving model to model.h5
# Epoch 138/400
# 47/47 - 50s - loss: 0.0604 - val_loss: 0.1266
#
# Epoch 00138: val_loss did not improve from 0.12640
# Epoch 139/400
# 47/47 - 50s - loss: 0.0607 - val_loss: 0.1235
#
# Epoch 00139: val_loss improved from 0.12640 to 0.12348, saving model to model.h5
# Epoch 140/400
# 47/47 - 50s - loss: 0.0567 - val_loss: 0.1204
#
# Epoch 00140: val_loss improved from 0.12348 to 0.12043, saving model to model.h5
# Epoch 141/400
# 47/47 - 50s - loss: 0.0538 - val_loss: 0.1190
#
# Epoch 00141: val_loss improved from 0.12043 to 0.11904, saving model to model.h5
# Epoch 142/400
# 47/47 - 50s - loss: 0.0511 - val_loss: 0.1178
#
# Epoch 00142: val_loss improved from 0.11904 to 0.11778, saving model to model.h5
# Epoch 143/400
# 47/47 - 50s - loss: 0.0498 - val_loss: 0.1153
#
# Epoch 00143: val_loss improved from 0.11778 to 0.11530, saving model to model.h5
# Epoch 144/400
# 47/47 - 50s - loss: 0.0474 - val_loss: 0.1142
#
# Epoch 00144: val_loss improved from 0.11530 to 0.11421, saving model to model.h5
# Epoch 145/400
# 47/47 - 50s - loss: 0.0459 - val_loss: 0.1134
#
# Epoch 00145: val_loss improved from 0.11421 to 0.11335, saving model to model.h5
# Epoch 146/400
# 47/47 - 50s - loss: 0.0448 - val_loss: 0.1123
#
# Epoch 00146: val_loss improved from 0.11335 to 0.11229, saving model to model.h5
# Epoch 147/400
# 47/47 - 50s - loss: 0.0444 - val_loss: 0.1142
#
# Epoch 00147: val_loss did not improve from 0.11229
# Epoch 148/400
# 47/47 - 50s - loss: 0.0480 - val_loss: 0.1205
#
# Epoch 00148: val_loss did not improve from 0.11229
# Epoch 149/400
# 47/47 - 50s - loss: 0.0510 - val_loss: 0.1192
#
# Epoch 00149: val_loss did not improve from 0.11229
# Epoch 150/400
# 47/47 - 50s - loss: 0.0486 - val_loss: 0.1145
#
# Epoch 00150: val_loss did not improve from 0.11229
# Epoch 151/400
# 47/47 - 50s - loss: 0.0453 - val_loss: 0.1113
#
# Epoch 00151: val_loss improved from 0.11229 to 0.11133, saving model to model.h5
# Epoch 152/400
# 47/47 - 50s - loss: 0.0431 - val_loss: 0.1105
#
# Epoch 00152: val_loss improved from 0.11133 to 0.11046, saving model to model.h5
# Epoch 153/400
# 47/47 - 50s - loss: 0.0408 - val_loss: 0.1171
#
# Epoch 00153: val_loss did not improve from 0.11046
# Epoch 154/400
# 47/47 - 49s - loss: 0.0422 - val_loss: 0.1104
#
# Epoch 00154: val_loss improved from 0.11046 to 0.11040, saving model to model.h5
# Epoch 155/400
# 47/47 - 49s - loss: 0.0399 - val_loss: 0.1093
#
# Epoch 00155: val_loss improved from 0.11040 to 0.10926, saving model to model.h5
# Epoch 156/400
# 47/47 - 49s - loss: 0.0392 - val_loss: 0.1084
#
# Epoch 00156: val_loss improved from 0.10926 to 0.10837, saving model to model.h5
# Epoch 157/400
# 47/47 - 49s - loss: 0.0372 - val_loss: 0.1064
#
# Epoch 00157: val_loss improved from 0.10837 to 0.10636, saving model to model.h5
# Epoch 158/400
# 47/47 - 49s - loss: 0.0349 - val_loss: 0.1053
#
# Epoch 00158: val_loss improved from 0.10636 to 0.10530, saving model to model.h5
# Epoch 159/400
# 47/47 - 49s - loss: 0.0341 - val_loss: 0.1057
#
# Epoch 00159: val_loss did not improve from 0.10530
# Epoch 160/400
# 47/47 - 49s - loss: 0.0336 - val_loss: 0.1044
#
# Epoch 00160: val_loss improved from 0.10530 to 0.10435, saving model to model.h5
# Epoch 161/400
# 47/47 - 49s - loss: 0.0318 - val_loss: 0.1025
#
# Epoch 00161: val_loss improved from 0.10435 to 0.10247, saving model to model.h5
# Epoch 162/400
# 47/47 - 49s - loss: 0.0312 - val_loss: 0.1027
#
# Epoch 00162: val_loss did not improve from 0.10247
# Epoch 163/400
# 47/47 - 49s - loss: 0.0322 - val_loss: 0.1039
#
# Epoch 00163: val_loss did not improve from 0.10247
# Epoch 164/400
# 47/47 - 49s - loss: 0.0372 - val_loss: 0.1105
#
# Epoch 00164: val_loss did not improve from 0.10247
# Epoch 165/400
# 47/47 - 49s - loss: 0.0453 - val_loss: 0.1125
#
# Epoch 00165: val_loss did not improve from 0.10247
# Epoch 166/400
# 47/47 - 49s - loss: 0.0507 - val_loss: 0.1161
#
# Epoch 00166: val_loss did not improve from 0.10247
# Epoch 167/400
# 47/47 - 49s - loss: 0.0452 - val_loss: 0.1108
#
# Epoch 00167: val_loss did not improve from 0.10247
# Epoch 168/400
# 47/47 - 49s - loss: 0.0380 - val_loss: 0.1054
#
# Epoch 00168: val_loss did not improve from 0.10247
# Epoch 169/400
# 47/47 - 49s - loss: 0.0323 - val_loss: 0.1009
#
# Epoch 00169: val_loss improved from 0.10247 to 0.10085, saving model to model.h5
# Epoch 170/400
# 47/47 - 49s - loss: 0.0282 - val_loss: 0.0986
#
# Epoch 00170: val_loss improved from 0.10085 to 0.09858, saving model to model.h5
# Epoch 171/400
# 47/47 - 49s - loss: 0.0264 - val_loss: 0.0980
#
# Epoch 00171: val_loss improved from 0.09858 to 0.09805, saving model to model.h5
# Epoch 172/400
# 47/47 - 49s - loss: 0.0252 - val_loss: 0.0981
#
# Epoch 00172: val_loss did not improve from 0.09805
# Epoch 173/400
# 47/47 - 49s - loss: 0.0252 - val_loss: 0.0978
#
# Epoch 00173: val_loss improved from 0.09805 to 0.09777, saving model to model.h5
# Epoch 174/400
# 47/47 - 49s - loss: 0.0239 - val_loss: 0.0970
#
# Epoch 00174: val_loss improved from 0.09777 to 0.09700, saving model to model.h5
# Epoch 175/400
# 47/47 - 50s - loss: 0.0238 - val_loss: 0.0995
#
# Epoch 00175: val_loss did not improve from 0.09700
# Epoch 176/400
# 47/47 - 50s - loss: 0.0238 - val_loss: 0.0984
#
# Epoch 00176: val_loss did not improve from 0.09700
# Epoch 177/400
# 47/47 - 51s - loss: 0.0233 - val_loss: 0.0964
#
# Epoch 00177: val_loss improved from 0.09700 to 0.09640, saving model to model.h5
# Epoch 178/400
# 47/47 - 51s - loss: 0.0221 - val_loss: 0.0956
#
# Epoch 00178: val_loss improved from 0.09640 to 0.09564, saving model to model.h5
# Epoch 179/400
# 47/47 - 50s - loss: 0.0220 - val_loss: 0.0957
#
# Epoch 00179: val_loss did not improve from 0.09564
# Epoch 180/400
# 47/47 - 50s - loss: 0.0210 - val_loss: 0.0968
#
# Epoch 00180: val_loss did not improve from 0.09564
# Epoch 181/400
# 47/47 - 50s - loss: 0.0209 - val_loss: 0.0956
#
# Epoch 00181: val_loss improved from 0.09564 to 0.09559, saving model to model.h5
# Epoch 182/400
# 47/47 - 50s - loss: 0.0206 - val_loss: 0.0960
#
# Epoch 00182: val_loss did not improve from 0.09559
# Epoch 183/400
# 47/47 - 50s - loss: 0.0208 - val_loss: 0.0954
#
# Epoch 00183: val_loss improved from 0.09559 to 0.09536, saving model to model.h5
# Epoch 184/400
# 47/47 - 50s - loss: 0.0202 - val_loss: 0.0971
#
# Epoch 00184: val_loss did not improve from 0.09536
# Epoch 185/400
# 47/47 - 50s - loss: 0.0202 - val_loss: 0.0950
#
# Epoch 00185: val_loss improved from 0.09536 to 0.09501, saving model to model.h5
# Epoch 186/400
# 47/47 - 50s - loss: 0.0195 - val_loss: 0.0961
#
# Epoch 00186: val_loss did not improve from 0.09501
# Epoch 187/400
# 47/47 - 50s - loss: 0.0211 - val_loss: 0.0984
#
# Epoch 00187: val_loss did not improve from 0.09501
# Epoch 188/400
# 47/47 - 50s - loss: 0.0227 - val_loss: 0.0976
#
# Epoch 00188: val_loss did not improve from 0.09501
# Epoch 189/400
# 47/47 - 50s - loss: 0.0238 - val_loss: 0.1019
#
# Epoch 00189: val_loss did not improve from 0.09501
# Epoch 190/400
# 47/47 - 50s - loss: 0.0272 - val_loss: 0.1044
#
# Epoch 00190: val_loss did not improve from 0.09501
# Epoch 191/400
# 47/47 - 50s - loss: 0.0296 - val_loss: 0.1061
#
# Epoch 00191: val_loss did not improve from 0.09501
# Epoch 192/400
# 47/47 - 50s - loss: 0.0303 - val_loss: 0.1040
#
# Epoch 00192: val_loss did not improve from 0.09501
# Epoch 193/400
# 47/47 - 50s - loss: 0.0273 - val_loss: 0.0992
#
# Epoch 00193: val_loss did not improve from 0.09501
# Epoch 194/400
# 47/47 - 50s - loss: 0.0238 - val_loss: 0.0969
#
# Epoch 00194: val_loss did not improve from 0.09501
# Epoch 195/400
# 47/47 - 50s - loss: 0.0214 - val_loss: 0.0963
#
# Epoch 00195: val_loss did not improve from 0.09501
# Epoch 196/400
# 47/47 - 50s - loss: 0.0202 - val_loss: 0.0960
#
# Epoch 00196: val_loss did not improve from 0.09501
# Epoch 197/400
# 47/47 - 50s - loss: 0.0195 - val_loss: 0.0945
#
# Epoch 00197: val_loss improved from 0.09501 to 0.09455, saving model to model.h5
# Epoch 198/400
# 47/47 - 50s - loss: 0.0179 - val_loss: 0.0937
#
# Epoch 00198: val_loss improved from 0.09455 to 0.09373, saving model to model.h5
# Epoch 199/400
# 47/47 - 50s - loss: 0.0169 - val_loss: 0.0933
#
# Epoch 00199: val_loss improved from 0.09373 to 0.09333, saving model to model.h5
# Epoch 200/400
# 47/47 - 50s - loss: 0.0175 - val_loss: 0.0938
#
# Epoch 00200: val_loss did not improve from 0.09333
# Epoch 201/400
# 47/47 - 50s - loss: 0.0174 - val_loss: 0.0932
#
# Epoch 00201: val_loss improved from 0.09333 to 0.09321, saving model to model.h5
# Epoch 202/400
# 47/47 - 50s - loss: 0.0163 - val_loss: 0.0937
#
# Epoch 00202: val_loss did not improve from 0.09321
# Epoch 203/400
# 47/47 - 50s - loss: 0.0165 - val_loss: 0.0937
#
# Epoch 00203: val_loss did not improve from 0.09321
# Epoch 204/400
# 47/47 - 51s - loss: 0.0173 - val_loss: 0.0940
#
# Epoch 00204: val_loss did not improve from 0.09321
# Epoch 205/400
# 47/47 - 51s - loss: 0.0173 - val_loss: 0.0935
#
# Epoch 00205: val_loss did not improve from 0.09321
# Epoch 206/400
# 47/47 - 51s - loss: 0.0164 - val_loss: 0.0948
#
# Epoch 00206: val_loss did not improve from 0.09321
# Epoch 207/400
# 47/47 - 51s - loss: 0.0165 - val_loss: 0.0952
#
# Epoch 00207: val_loss did not improve from 0.09321
# Epoch 208/400
# 47/47 - 51s - loss: 0.0167 - val_loss: 0.0934
#
# Epoch 00208: val_loss did not improve from 0.09321
# Epoch 209/400
# 47/47 - 52s - loss: 0.0163 - val_loss: 0.0941
#
# Epoch 00209: val_loss did not improve from 0.09321
# Epoch 210/400
# 47/47 - 52s - loss: 0.0157 - val_loss: 0.0940
#
# Epoch 00210: val_loss did not improve from 0.09321
# Epoch 211/400
# 47/47 - 52s - loss: 0.0151 - val_loss: 0.0937
#
# Epoch 00211: val_loss did not improve from 0.09321
# Epoch 212/400
# 47/47 - 52s - loss: 0.0152 - val_loss: 0.0922
#
# Epoch 00212: val_loss improved from 0.09321 to 0.09219, saving model to model.h5
# Epoch 213/400
# 47/47 - 52s - loss: 0.0149 - val_loss: 0.0932
#
# Epoch 00213: val_loss did not improve from 0.09219
# Epoch 214/400
# 47/47 - 52s - loss: 0.0151 - val_loss: 0.0938
#
# Epoch 00214: val_loss did not improve from 0.09219
# Epoch 215/400
# 47/47 - 52s - loss: 0.0152 - val_loss: 0.0941
#
# Epoch 00215: val_loss did not improve from 0.09219
# Epoch 216/400
# 47/47 - 52s - loss: 0.0158 - val_loss: 0.0944
#
# Epoch 00216: val_loss did not improve from 0.09219
# Epoch 217/400
# 47/47 - 52s - loss: 0.0157 - val_loss: 0.0929
#
# Epoch 00217: val_loss did not improve from 0.09219
# Epoch 218/400
# 47/47 - 52s - loss: 0.0160 - val_loss: 0.0955
#
# Epoch 00218: val_loss did not improve from 0.09219
# Epoch 219/400
# 47/47 - 52s - loss: 0.0170 - val_loss: 0.0966
#
# Epoch 00219: val_loss did not improve from 0.09219
# Epoch 220/400
# 47/47 - 52s - loss: 0.0180 - val_loss: 0.0964
#
# Epoch 00220: val_loss did not improve from 0.09219
# Epoch 221/400
# 47/47 - 52s - loss: 0.0188 - val_loss: 0.0964
#
# Epoch 00221: val_loss did not improve from 0.09219
# Epoch 222/400
# 47/47 - 52s - loss: 0.0208 - val_loss: 0.1030
#
# Epoch 00222: val_loss did not improve from 0.09219
# Epoch 223/400
# 47/47 - 52s - loss: 0.0226 - val_loss: 0.0982
#
# Epoch 00223: val_loss did not improve from 0.09219
# Epoch 224/400
# 47/47 - 51s - loss: 0.0223 - val_loss: 0.1014
#
# Epoch 00224: val_loss did not improve from 0.09219
# Epoch 225/400
# 47/47 - 51s - loss: 0.0237 - val_loss: 0.0987
#
# Epoch 00225: val_loss did not improve from 0.09219
# Epoch 226/400
# 47/47 - 52s - loss: 0.0243 - val_loss: 0.1024
#
# Epoch 00226: val_loss did not improve from 0.09219
# Epoch 227/400
# 47/47 - 51s - loss: 0.0263 - val_loss: 0.1018
#
# Epoch 00227: val_loss did not improve from 0.09219
# Epoch 228/400
# 47/47 - 52s - loss: 0.0236 - val_loss: 0.0993
#
# Epoch 00228: val_loss did not improve from 0.09219
# Epoch 229/400
# 47/47 - 52s - loss: 0.0228 - val_loss: 0.0977
#
# Epoch 00229: val_loss did not improve from 0.09219
# Epoch 230/400
# 47/47 - 52s - loss: 0.0191 - val_loss: 0.0955
#
# Epoch 00230: val_loss did not improve from 0.09219
# Epoch 231/400
# 47/47 - 52s - loss: 0.0164 - val_loss: 0.0940
#
# Epoch 00231: val_loss did not improve from 0.09219
# Epoch 232/400
# 47/47 - 51s - loss: 0.0140 - val_loss: 0.0919
#
# Epoch 00232: val_loss improved from 0.09219 to 0.09186, saving model to model.h5
# Epoch 233/400
# 47/47 - 51s - loss: 0.0120 - val_loss: 0.0915
#
# Epoch 00233: val_loss improved from 0.09186 to 0.09146, saving model to model.h5
# Epoch 234/400
# 47/47 - 51s - loss: 0.0115 - val_loss: 0.0913
#
# Epoch 00234: val_loss improved from 0.09146 to 0.09131, saving model to model.h5
# Epoch 235/400
# 47/47 - 51s - loss: 0.0114 - val_loss: 0.0916
#
# Epoch 00235: val_loss did not improve from 0.09131
# Epoch 236/400
# 47/47 - 51s - loss: 0.0118 - val_loss: 0.0915
#
# Epoch 00236: val_loss did not improve from 0.09131
# Epoch 237/400
# 47/47 - 51s - loss: 0.0117 - val_loss: 0.0913
#
# Epoch 00237: val_loss did not improve from 0.09131
# Epoch 238/400
# 47/47 - 51s - loss: 0.0117 - val_loss: 0.0915
#
# Epoch 00238: val_loss did not improve from 0.09131
# Epoch 239/400
# 47/47 - 51s - loss: 0.0115 - val_loss: 0.0916
#
# Epoch 00239: val_loss did not improve from 0.09131
# Epoch 240/400
# 47/47 - 51s - loss: 0.0109 - val_loss: 0.0909
#
# Epoch 00240: val_loss improved from 0.09131 to 0.09094, saving model to model.h5
# Epoch 241/400
# 47/47 - 51s - loss: 0.0108 - val_loss: 0.0909
#
# Epoch 00241: val_loss improved from 0.09094 to 0.09091, saving model to model.h5
# Epoch 242/400
# 47/47 - 51s - loss: 0.0105 - val_loss: 0.0920
#
# Epoch 00242: val_loss did not improve from 0.09091
# Epoch 243/400
# 47/47 - 51s - loss: 0.0103 - val_loss: 0.0907
#
# Epoch 00243: val_loss improved from 0.09091 to 0.09071, saving model to model.h5
# Epoch 244/400
# 47/47 - 51s - loss: 0.0104 - val_loss: 0.0912
#
# Epoch 00244: val_loss did not improve from 0.09071
# Epoch 245/400
# 47/47 - 51s - loss: 0.0112 - val_loss: 0.0917
#
# Epoch 00245: val_loss did not improve from 0.09071
# Epoch 246/400
# 47/47 - 51s - loss: 0.0107 - val_loss: 0.0915
#
# Epoch 00246: val_loss did not improve from 0.09071
# Epoch 247/400
# 47/47 - 51s - loss: 0.0105 - val_loss: 0.0913
#
# Epoch 00247: val_loss did not improve from 0.09071
# Epoch 248/400
# 47/47 - 51s - loss: 0.0113 - val_loss: 0.0925
#
# Epoch 00248: val_loss did not improve from 0.09071
# Epoch 249/400
# 47/47 - 51s - loss: 0.0135 - val_loss: 0.0954
#
# Epoch 00249: val_loss did not improve from 0.09071
# Epoch 250/400
# 47/47 - 51s - loss: 0.0151 - val_loss: 0.0960
#
# Epoch 00250: val_loss did not improve from 0.09071
# Epoch 251/400
# 47/47 - 51s - loss: 0.0174 - val_loss: 0.0986
#
# Epoch 00251: val_loss did not improve from 0.09071
# Epoch 252/400
# 47/47 - 51s - loss: 0.0213 - val_loss: 0.1015
#
# Epoch 00252: val_loss did not improve from 0.09071
# Epoch 253/400
# 47/47 - 51s - loss: 0.0253 - val_loss: 0.1026
#
# Epoch 00253: val_loss did not improve from 0.09071
# Epoch 254/400
# 47/47 - 51s - loss: 0.0223 - val_loss: 0.0998
#
# Epoch 00254: val_loss did not improve from 0.09071
# Epoch 255/400
# 47/47 - 51s - loss: 0.0184 - val_loss: 0.0974
#
# Epoch 00255: val_loss did not improve from 0.09071
# Epoch 256/400
# 47/47 - 51s - loss: 0.0161 - val_loss: 0.0958
#
# Epoch 00256: val_loss did not improve from 0.09071
# Epoch 257/400
# 47/47 - 52s - loss: 0.0144 - val_loss: 0.0933
#
# Epoch 00257: val_loss did not improve from 0.09071
# Epoch 258/400
# 47/47 - 53s - loss: 0.0118 - val_loss: 0.0915
#
# Epoch 00258: val_loss did not improve from 0.09071
# Epoch 259/400
# 47/47 - 50s - loss: 0.0103 - val_loss: 0.0909
#
# Epoch 00259: val_loss did not improve from 0.09071
# Epoch 260/400
# 47/47 - 50s - loss: 0.0103 - val_loss: 0.0913
#
# Epoch 00260: val_loss did not improve from 0.09071
# Epoch 261/400
# 47/47 - 50s - loss: 0.0096 - val_loss: 0.0904
#
# Epoch 00261: val_loss improved from 0.09071 to 0.09045, saving model to model.h5
# Epoch 262/400
# 47/47 - 50s - loss: 0.0100 - val_loss: 0.0916
#
# Epoch 00262: val_loss did not improve from 0.09045
# Epoch 263/400
# 47/47 - 50s - loss: 0.0119 - val_loss: 0.0936
#
# Epoch 00263: val_loss did not improve from 0.09045
# Epoch 264/400
# 47/47 - 50s - loss: 0.0123 - val_loss: 0.0925
#
# Epoch 00264: val_loss did not improve from 0.09045
# Epoch 265/400
# 47/47 - 50s - loss: 0.0112 - val_loss: 0.0926
#
# Epoch 00265: val_loss did not improve from 0.09045
# Epoch 266/400
# 47/47 - 50s - loss: 0.0114 - val_loss: 0.0942
#
# Epoch 00266: val_loss did not improve from 0.09045
# Epoch 267/400
# 47/47 - 50s - loss: 0.0126 - val_loss: 0.0967
#
# Epoch 00267: val_loss did not improve from 0.09045
# Epoch 268/400
# 47/47 - 50s - loss: 0.0134 - val_loss: 0.0950
#
# Epoch 00268: val_loss did not improve from 0.09045
# Epoch 269/400
# 47/47 - 50s - loss: 0.0139 - val_loss: 0.0947
#
# Epoch 00269: val_loss did not improve from 0.09045
# Epoch 270/400
# 47/47 - 50s - loss: 0.0133 - val_loss: 0.0939
#
# Epoch 00270: val_loss did not improve from 0.09045
# Epoch 271/400
# 47/47 - 50s - loss: 0.0114 - val_loss: 0.0923
#
# Epoch 00271: val_loss did not improve from 0.09045
# Epoch 272/400
# 47/47 - 50s - loss: 0.0110 - val_loss: 0.0928
#
# Epoch 00272: val_loss did not improve from 0.09045
# Epoch 273/400
# 47/47 - 50s - loss: 0.0112 - val_loss: 0.0947
#
# Epoch 00273: val_loss did not improve from 0.09045
# Epoch 274/400
# 47/47 - 50s - loss: 0.0111 - val_loss: 0.0936
#
# Epoch 00274: val_loss did not improve from 0.09045
# Epoch 275/400
# 47/47 - 50s - loss: 0.0113 - val_loss: 0.0934
#
# Epoch 00275: val_loss did not improve from 0.09045
# Epoch 276/400
# 47/47 - 50s - loss: 0.0130 - val_loss: 0.0947
#
# Epoch 00276: val_loss did not improve from 0.09045
# Epoch 277/400
# 47/47 - 50s - loss: 0.0143 - val_loss: 0.0958
#
# Epoch 00277: val_loss did not improve from 0.09045
# Epoch 278/400
# 47/47 - 50s - loss: 0.0130 - val_loss: 0.0934
#
# Epoch 00278: val_loss did not improve from 0.09045
# Epoch 279/400
# 47/47 - 50s - loss: 0.0109 - val_loss: 0.0917
#
# Epoch 00279: val_loss did not improve from 0.09045
# Epoch 280/400
# 47/47 - 50s - loss: 0.0099 - val_loss: 0.0924
#
# Epoch 00280: val_loss did not improve from 0.09045
# Epoch 281/400
# 47/47 - 50s - loss: 0.0094 - val_loss: 0.0910
#
# Epoch 00281: val_loss did not improve from 0.09045
# Epoch 282/400
# 47/47 - 50s - loss: 0.0086 - val_loss: 0.0911
#
# Epoch 00282: val_loss did not improve from 0.09045
# Epoch 283/400
# 47/47 - 50s - loss: 0.0085 - val_loss: 0.0903
#
# Epoch 00283: val_loss improved from 0.09045 to 0.09033, saving model to model.h5
# Epoch 284/400
# 47/47 - 51s - loss: 0.0087 - val_loss: 0.0917
#
# Epoch 00284: val_loss did not improve from 0.09033
# Epoch 285/400
# 47/47 - 51s - loss: 0.0088 - val_loss: 0.0913
#
# Epoch 00285: val_loss did not improve from 0.09033
# Epoch 286/400
# 47/47 - 51s - loss: 0.0090 - val_loss: 0.0916
#
# Epoch 00286: val_loss did not improve from 0.09033
# Epoch 287/400
# 47/47 - 51s - loss: 0.0091 - val_loss: 0.0916
#
# Epoch 00287: val_loss did not improve from 0.09033
# Epoch 288/400
# 47/47 - 51s - loss: 0.0094 - val_loss: 0.0917
#
# Epoch 00288: val_loss did not improve from 0.09033
# Epoch 289/400
# 47/47 - 51s - loss: 0.0089 - val_loss: 0.0918
#
# Epoch 00289: val_loss did not improve from 0.09033
# Epoch 290/400
# 47/47 - 52s - loss: 0.0089 - val_loss: 0.0934
#
# Epoch 00290: val_loss did not improve from 0.09033
# Epoch 291/400
# 47/47 - 52s - loss: 0.0101 - val_loss: 0.0952
#
# Epoch 00291: val_loss did not improve from 0.09033
# Epoch 292/400
# 47/47 - 52s - loss: 0.0141 - val_loss: 0.0987
#
# Epoch 00292: val_loss did not improve from 0.09033
# Epoch 293/400
# 47/47 - 51s - loss: 0.0208 - val_loss: 0.1076
#
# Epoch 00293: val_loss did not improve from 0.09033
# Epoch 294/400
# 47/47 - 51s - loss: 0.0255 - val_loss: 0.1073
#
# Epoch 00294: val_loss did not improve from 0.09033
# Epoch 295/400
# 47/47 - 51s - loss: 0.0248 - val_loss: 0.1040
#
# Epoch 00295: val_loss did not improve from 0.09033
# Epoch 296/400
# 47/47 - 51s - loss: 0.0223 - val_loss: 0.1014
#
# Epoch 00296: val_loss did not improve from 0.09033
# Epoch 297/400
# 47/47 - 51s - loss: 0.0187 - val_loss: 0.0951
#
# Epoch 00297: val_loss did not improve from 0.09033
# Epoch 298/400
# 47/47 - 51s - loss: 0.0128 - val_loss: 0.0934
#
# Epoch 00298: val_loss did not improve from 0.09033
# Epoch 299/400
# 47/47 - 51s - loss: 0.0109 - val_loss: 0.0918
#
# Epoch 00299: val_loss did not improve from 0.09033
# Epoch 300/400
# 47/47 - 52s - loss: 0.0091 - val_loss: 0.0913
#
# Epoch 00300: val_loss did not improve from 0.09033
# Epoch 301/400
# 47/47 - 52s - loss: 0.0083 - val_loss: 0.0911
#
# Epoch 00301: val_loss did not improve from 0.09033
# Epoch 302/400
# 47/47 - 51s - loss: 0.0083 - val_loss: 0.0912
#
# Epoch 00302: val_loss did not improve from 0.09033
# Epoch 303/400
# 47/47 - 51s - loss: 0.0079 - val_loss: 0.0911
#
# Epoch 00303: val_loss did not improve from 0.09033
# Epoch 304/400
# 47/47 - 50s - loss: 0.0077 - val_loss: 0.0909
#
# Epoch 00304: val_loss did not improve from 0.09033
# Epoch 305/400
# 47/47 - 51s - loss: 0.0074 - val_loss: 0.0907
#
# Epoch 00305: val_loss did not improve from 0.09033
# Epoch 306/400
# 47/47 - 50s - loss: 0.0076 - val_loss: 0.0914
#
# Epoch 00306: val_loss did not improve from 0.09033
# Epoch 307/400
# 47/47 - 51s - loss: 0.0080 - val_loss: 0.0913
#
# Epoch 00307: val_loss did not improve from 0.09033
# Epoch 308/400
# 47/47 - 52s - loss: 0.0094 - val_loss: 0.0926
#
# Epoch 00308: val_loss did not improve from 0.09033
# Epoch 309/400
# 47/47 - 52s - loss: 0.0097 - val_loss: 0.0926
#
# Epoch 00309: val_loss did not improve from 0.09033
# Epoch 310/400
# 47/47 - 51s - loss: 0.0103 - val_loss: 0.0952
#
# Epoch 00310: val_loss did not improve from 0.09033
# Epoch 311/400
# 47/47 - 51s - loss: 0.0121 - val_loss: 0.0957
#
# Epoch 00311: val_loss did not improve from 0.09033
# Epoch 312/400
# 47/47 - 50s - loss: 0.0132 - val_loss: 0.0989
#
# Epoch 00312: val_loss did not improve from 0.09033
# Epoch 313/400
# 47/47 - 51s - loss: 0.0143 - val_loss: 0.0964
#
# Epoch 00313: val_loss did not improve from 0.09033
# Epoch 314/400
# 47/47 - 51s - loss: 0.0137 - val_loss: 0.0969
#
# Epoch 00314: val_loss did not improve from 0.09033
# Epoch 315/400
# 47/47 - 51s - loss: 0.0125 - val_loss: 0.0946
#
# Epoch 00315: val_loss did not improve from 0.09033
# Epoch 316/400
# 47/47 - 51s - loss: 0.0107 - val_loss: 0.0933
#
# Epoch 00316: val_loss did not improve from 0.09033
# Epoch 317/400
# 47/47 - 51s - loss: 0.0095 - val_loss: 0.0926
#
# Epoch 00317: val_loss did not improve from 0.09033
# Epoch 318/400
# 47/47 - 50s - loss: 0.0090 - val_loss: 0.0921
#
# Epoch 00318: val_loss did not improve from 0.09033
# Epoch 319/400
# 47/47 - 51s - loss: 0.0082 - val_loss: 0.0918
#
# Epoch 00319: val_loss did not improve from 0.09033
# Epoch 320/400
# 47/47 - 51s - loss: 0.0082 - val_loss: 0.0913
#
# Epoch 00320: val_loss did not improve from 0.09033
# Epoch 321/400
# 47/47 - 51s - loss: 0.0078 - val_loss: 0.0919
#
# Epoch 00321: val_loss did not improve from 0.09033
# Epoch 322/400
# 47/47 - 51s - loss: 0.0082 - val_loss: 0.0917
#
# Epoch 00322: val_loss did not improve from 0.09033
# Epoch 323/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0912
#
# Epoch 00323: val_loss did not improve from 0.09033
# Epoch 324/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0923
#
# Epoch 00324: val_loss did not improve from 0.09033
# Epoch 325/400
# 47/47 - 52s - loss: 0.0082 - val_loss: 0.0930
#
# Epoch 00325: val_loss did not improve from 0.09033
# Epoch 326/400
# 47/47 - 52s - loss: 0.0098 - val_loss: 0.0936
#
# Epoch 00326: val_loss did not improve from 0.09033
# Epoch 327/400
# 47/47 - 52s - loss: 0.0101 - val_loss: 0.0944
#
# Epoch 00327: val_loss did not improve from 0.09033
# Epoch 328/400
# 47/47 - 52s - loss: 0.0095 - val_loss: 0.0942
#
# Epoch 00328: val_loss did not improve from 0.09033
# Epoch 329/400
# 47/47 - 51s - loss: 0.0109 - val_loss: 0.0947
#
# Epoch 00329: val_loss did not improve from 0.09033
# Epoch 330/400
# 47/47 - 52s - loss: 0.0107 - val_loss: 0.0946
#
# Epoch 00330: val_loss did not improve from 0.09033
# Epoch 331/400
# 47/47 - 51s - loss: 0.0099 - val_loss: 0.0944
#
# Epoch 00331: val_loss did not improve from 0.09033
# Epoch 332/400
# 47/47 - 51s - loss: 0.0090 - val_loss: 0.0929
#
# Epoch 00332: val_loss did not improve from 0.09033
# Epoch 333/400
# 47/47 - 52s - loss: 0.0084 - val_loss: 0.0936
#
# Epoch 00333: val_loss did not improve from 0.09033
# Epoch 334/400
# 47/47 - 52s - loss: 0.0082 - val_loss: 0.0941
#
# Epoch 00334: val_loss did not improve from 0.09033
# Epoch 335/400
# 47/47 - 51s - loss: 0.0097 - val_loss: 0.0961
#
# Epoch 00335: val_loss did not improve from 0.09033
# Epoch 336/400
# 47/47 - 51s - loss: 0.0114 - val_loss: 0.0953
#
# Epoch 00336: val_loss did not improve from 0.09033
# Epoch 337/400
# 47/47 - 51s - loss: 0.0136 - val_loss: 0.0992
#
# Epoch 00337: val_loss did not improve from 0.09033
# Epoch 338/400
# 47/47 - 50s - loss: 0.0178 - val_loss: 0.1032
#
# Epoch 00338: val_loss did not improve from 0.09033
# Epoch 339/400
# 47/47 - 51s - loss: 0.0210 - val_loss: 0.1090
#
# Epoch 00339: val_loss did not improve from 0.09033
# Epoch 340/400
# 47/47 - 51s - loss: 0.0245 - val_loss: 0.1065
#
# Epoch 00340: val_loss did not improve from 0.09033
# Epoch 341/400
# 47/47 - 50s - loss: 0.0208 - val_loss: 0.0990
#
# Epoch 00341: val_loss did not improve from 0.09033
# Epoch 342/400
# 47/47 - 51s - loss: 0.0151 - val_loss: 0.0959
#
# Epoch 00342: val_loss did not improve from 0.09033
# Epoch 343/400
# 47/47 - 52s - loss: 0.0112 - val_loss: 0.0937
#
# Epoch 00343: val_loss did not improve from 0.09033
# Epoch 344/400
# 47/47 - 52s - loss: 0.0091 - val_loss: 0.0937
#
# Epoch 00344: val_loss did not improve from 0.09033
# Epoch 345/400
# 47/47 - 52s - loss: 0.0078 - val_loss: 0.0926
#
# Epoch 00345: val_loss did not improve from 0.09033
# Epoch 346/400
# 47/47 - 51s - loss: 0.0078 - val_loss: 0.0930
#
# Epoch 00346: val_loss did not improve from 0.09033
# Epoch 347/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0924
#
# Epoch 00347: val_loss did not improve from 0.09033
# Epoch 348/400
# 47/47 - 52s - loss: 0.0070 - val_loss: 0.0921
#
# Epoch 00348: val_loss did not improve from 0.09033
# Epoch 349/400
# 47/47 - 51s - loss: 0.0069 - val_loss: 0.0929
#
# Epoch 00349: val_loss did not improve from 0.09033
# Epoch 350/400
# 47/47 - 52s - loss: 0.0070 - val_loss: 0.0924
#
# Epoch 00350: val_loss did not improve from 0.09033
# Epoch 351/400
# 47/47 - 50s - loss: 0.0073 - val_loss: 0.0954
#
# Epoch 00351: val_loss did not improve from 0.09033
# Epoch 352/400
# 47/47 - 51s - loss: 0.0088 - val_loss: 0.0935
#
# Epoch 00352: val_loss did not improve from 0.09033
# Epoch 353/400
# 47/47 - 52s - loss: 0.0080 - val_loss: 0.0934
#
# Epoch 00353: val_loss did not improve from 0.09033
# Epoch 354/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0933
#
# Epoch 00354: val_loss did not improve from 0.09033
# Epoch 355/400
# 47/47 - 51s - loss: 0.0071 - val_loss: 0.0926
#
# Epoch 00355: val_loss did not improve from 0.09033
# Epoch 356/400
# 47/47 - 51s - loss: 0.0068 - val_loss: 0.0924
#
# Epoch 00356: val_loss did not improve from 0.09033
# Epoch 357/400
# 47/47 - 51s - loss: 0.0066 - val_loss: 0.0924
#
# Epoch 00357: val_loss did not improve from 0.09033
# Epoch 358/400
# 47/47 - 50s - loss: 0.0065 - val_loss: 0.0926
#
# Epoch 00358: val_loss did not improve from 0.09033
# Epoch 359/400
# 47/47 - 51s - loss: 0.0066 - val_loss: 0.0924
#
# Epoch 00359: val_loss did not improve from 0.09033
# Epoch 360/400
# 47/47 - 51s - loss: 0.0066 - val_loss: 0.0924
#
# Epoch 00360: val_loss did not improve from 0.09033
# Epoch 361/400
# 47/47 - 51s - loss: 0.0067 - val_loss: 0.0927
#
# Epoch 00361: val_loss did not improve from 0.09033
# Epoch 362/400
# 47/47 - 52s - loss: 0.0067 - val_loss: 0.0929
#
# Epoch 00362: val_loss did not improve from 0.09033
# Epoch 363/400
# 47/47 - 52s - loss: 0.0069 - val_loss: 0.0946
#
# Epoch 00363: val_loss did not improve from 0.09033
# Epoch 364/400
# 47/47 - 51s - loss: 0.0083 - val_loss: 0.0945
#
# Epoch 00364: val_loss did not improve from 0.09033
# Epoch 365/400
# 47/47 - 50s - loss: 0.0096 - val_loss: 0.0956
#
# Epoch 00365: val_loss did not improve from 0.09033
# Epoch 366/400
# 47/47 - 51s - loss: 0.0092 - val_loss: 0.0939
#
# Epoch 00366: val_loss did not improve from 0.09033
# Epoch 367/400
# 47/47 - 52s - loss: 0.0081 - val_loss: 0.0928
#
# Epoch 00367: val_loss did not improve from 0.09033
# Epoch 368/400
# 47/47 - 51s - loss: 0.0074 - val_loss: 0.0931
#
# Epoch 00368: val_loss did not improve from 0.09033
# Epoch 369/400
# 47/47 - 50s - loss: 0.0074 - val_loss: 0.0938
#
# Epoch 00369: val_loss did not improve from 0.09033
# Epoch 370/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0937
#
# Epoch 00370: val_loss did not improve from 0.09033
# Epoch 371/400
# 47/47 - 51s - loss: 0.0077 - val_loss: 0.0949
#
# Epoch 00371: val_loss did not improve from 0.09033
# Epoch 372/400
# 47/47 - 50s - loss: 0.0086 - val_loss: 0.0956
#
# Epoch 00372: val_loss did not improve from 0.09033
# Epoch 373/400
# 47/47 - 51s - loss: 0.0109 - val_loss: 0.0959
#
# Epoch 00373: val_loss did not improve from 0.09033
# Epoch 374/400
# 47/47 - 50s - loss: 0.0110 - val_loss: 0.0982
#
# Epoch 00374: val_loss did not improve from 0.09033
# Epoch 375/400
# 47/47 - 51s - loss: 0.0143 - val_loss: 0.1021
#
# Epoch 00375: val_loss did not improve from 0.09033
# Epoch 376/400
# 47/47 - 52s - loss: 0.0176 - val_loss: 0.1039
#
# Epoch 00376: val_loss did not improve from 0.09033
# Epoch 377/400
# 47/47 - 52s - loss: 0.0229 - val_loss: 0.1044
#
# Epoch 00377: val_loss did not improve from 0.09033
# Epoch 378/400
# 47/47 - 51s - loss: 0.0197 - val_loss: 0.1005
#
# Epoch 00378: val_loss did not improve from 0.09033
# Epoch 379/400
# 47/47 - 51s - loss: 0.0146 - val_loss: 0.0978
#
# Epoch 00379: val_loss did not improve from 0.09033
# Epoch 380/400
# 47/47 - 51s - loss: 0.0109 - val_loss: 0.0956
#
# Epoch 00380: val_loss did not improve from 0.09033
# Epoch 381/400
# 47/47 - 51s - loss: 0.0091 - val_loss: 0.0946
#
# Epoch 00381: val_loss did not improve from 0.09033
# Epoch 382/400
# 47/47 - 51s - loss: 0.0081 - val_loss: 0.0936
#
# Epoch 00382: val_loss did not improve from 0.09033
# Epoch 383/400
# 47/47 - 51s - loss: 0.0072 - val_loss: 0.0939
#
# Epoch 00383: val_loss did not improve from 0.09033
# Epoch 384/400
# 47/47 - 51s - loss: 0.0069 - val_loss: 0.0932
#
# Epoch 00384: val_loss did not improve from 0.09033
# Epoch 385/400
# 47/47 - 51s - loss: 0.0067 - val_loss: 0.0931
#
# Epoch 00385: val_loss did not improve from 0.09033
# Epoch 386/400
# 47/47 - 51s - loss: 0.0064 - val_loss: 0.0932
#
# Epoch 00386: val_loss did not improve from 0.09033
# Epoch 387/400
# 47/47 - 51s - loss: 0.0068 - val_loss: 0.0940
#
# Epoch 00387: val_loss did not improve from 0.09033
# Epoch 388/400
# 47/47 - 51s - loss: 0.0075 - val_loss: 0.0944
#
# Epoch 00388: val_loss did not improve from 0.09033
# Epoch 389/400
# 47/47 - 51s - loss: 0.0079 - val_loss: 0.0943
#
# Epoch 00389: val_loss did not improve from 0.09033
# Epoch 390/400
# 47/47 - 51s - loss: 0.0070 - val_loss: 0.0932
#
# Epoch 00390: val_loss did not improve from 0.09033
# Epoch 391/400
# 47/47 - 51s - loss: 0.0065 - val_loss: 0.0934
#
# Epoch 00391: val_loss did not improve from 0.09033
# Epoch 392/400
# 47/47 - 51s - loss: 0.0067 - val_loss: 0.0937
#
# Epoch 00392: val_loss did not improve from 0.09033
# Epoch 393/400
# 47/47 - 52s - loss: 0.0073 - val_loss: 0.0938
#
# Epoch 00393: val_loss did not improve from 0.09033
# Epoch 394/400
# 47/47 - 53s - loss: 0.0075 - val_loss: 0.0938
#
# Epoch 00394: val_loss did not improve from 0.09033
# Epoch 395/400
# 47/47 - 52s - loss: 0.0070 - val_loss: 0.0943
#
# Epoch 00395: val_loss did not improve from 0.09033
# Epoch 396/400
# 47/47 - 52s - loss: 0.0069 - val_loss: 0.0936
#
# Epoch 00396: val_loss did not improve from 0.09033
# Epoch 397/400
# 47/47 - 52s - loss: 0.0067 - val_loss: 0.0936
#
# Epoch 00397: val_loss did not improve from 0.09033
# Epoch 398/400
# 47/47 - 51s - loss: 0.0068 - val_loss: 0.0944
#
# Epoch 00398: val_loss did not improve from 0.09033
# Epoch 399/400
# 47/47 - 51s - loss: 0.0071 - val_loss: 0.0943
#
# Epoch 00399: val_loss did not improve from 0.09033
# Epoch 400/400
# 47/47 - 51s - loss: 0.0066 - val_loss: 0.0939
#
# Epoch 00400: val_loss did not improve from 0.09033

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-LowSaxon-both.pkl')
train = load_clean_sentences('english-LowSaxon-train.pkl')
test = load_clean_sentences('english-LowSaxon-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Low Saxon Vocabulary Size: %d' % ger_vocab_size)
print('Low Saxon  Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=200, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2539
# English Max Length: 38
# Low Saxon Vocabulary Size: 2725
# Low Saxon  Max Length: 40
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 40, 256)           697600
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 38, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 38, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 38, 2539)          652523
# =================================================================
# Total params: 2,400,747
# Trainable params: 2,400,747
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 47/47 - 55s - loss: 2.6638 - val_loss: 1.1948
#
# Epoch 00001: val_loss improved from inf to 1.19475, saving model to model.h5
# Epoch 2/200
# 47/47 - 48s - loss: 1.0757 - val_loss: 1.0314
#
# Epoch 00002: val_loss improved from 1.19475 to 1.03138, saving model to model.h5
# Epoch 3/200
# 47/47 - 48s - loss: 1.0145 - val_loss: 1.0071
#
# Epoch 00003: val_loss improved from 1.03138 to 1.00708, saving model to model.h5
# Epoch 4/200
# 47/47 - 48s - loss: 1.0017 - val_loss: 0.9854
#
# Epoch 00004: val_loss improved from 1.00708 to 0.98541, saving model to model.h5
# Epoch 5/200
# 47/47 - 48s - loss: 0.9773 - val_loss: 0.9686
#
# Epoch 00005: val_loss improved from 0.98541 to 0.96858, saving model to model.h5
# Epoch 6/200
# 47/47 - 48s - loss: 0.9628 - val_loss: 0.9535
#
# Epoch 00006: val_loss improved from 0.96858 to 0.95351, saving model to model.h5
# Epoch 7/200
# 47/47 - 48s - loss: 0.9477 - val_loss: 0.9368
#
# Epoch 00007: val_loss improved from 0.95351 to 0.93685, saving model to model.h5
# Epoch 8/200
# 47/47 - 48s - loss: 0.9343 - val_loss: 0.9274
#
# Epoch 00008: val_loss improved from 0.93685 to 0.92736, saving model to model.h5
# Epoch 9/200
# 47/47 - 48s - loss: 0.9168 - val_loss: 0.9160
#
# Epoch 00009: val_loss improved from 0.92736 to 0.91605, saving model to model.h5
# Epoch 10/200
# 47/47 - 47s - loss: 0.8966 - val_loss: 0.8912
#
# Epoch 00010: val_loss improved from 0.91605 to 0.89122, saving model to model.h5
# Epoch 11/200
# 47/47 - 47s - loss: 0.8809 - val_loss: 0.8795
#
# Epoch 00011: val_loss improved from 0.89122 to 0.87954, saving model to model.h5
# Epoch 12/200
# 47/47 - 47s - loss: 0.8727 - val_loss: 0.8752
#
# Epoch 00012: val_loss improved from 0.87954 to 0.87517, saving model to model.h5
# Epoch 13/200
# 47/47 - 47s - loss: 0.8657 - val_loss: 0.8692
#
# Epoch 00013: val_loss improved from 0.87517 to 0.86923, saving model to model.h5
# Epoch 14/200
# 47/47 - 47s - loss: 0.8614 - val_loss: 0.8711
#
# Epoch 00014: val_loss did not improve from 0.86923
# Epoch 15/200
# 47/47 - 47s - loss: 0.8827 - val_loss: 0.8706
#
# Epoch 00015: val_loss did not improve from 0.86923
# Epoch 16/200
# 47/47 - 47s - loss: 0.8596 - val_loss: 0.8609
#
# Epoch 00016: val_loss improved from 0.86923 to 0.86091, saving model to model.h5
# Epoch 17/200
# 47/47 - 47s - loss: 0.8507 - val_loss: 0.8558
#
# Epoch 00017: val_loss improved from 0.86091 to 0.85582, saving model to model.h5
# Epoch 18/200
# 47/47 - 47s - loss: 0.8454 - val_loss: 0.8518
#
# Epoch 00018: val_loss improved from 0.85582 to 0.85185, saving model to model.h5
# Epoch 19/200
# 47/47 - 47s - loss: 0.8409 - val_loss: 0.8478
#
# Epoch 00019: val_loss improved from 0.85185 to 0.84777, saving model to model.h5
# Epoch 20/200
# 47/47 - 47s - loss: 0.8393 - val_loss: 0.8460
#
# Epoch 00020: val_loss improved from 0.84777 to 0.84598, saving model to model.h5
# Epoch 21/200
# 47/47 - 47s - loss: 0.8336 - val_loss: 0.8396
#
# Epoch 00021: val_loss improved from 0.84598 to 0.83961, saving model to model.h5
# Epoch 22/200
# 47/47 - 47s - loss: 0.8296 - val_loss: 0.8396
#
# Epoch 00022: val_loss improved from 0.83961 to 0.83961, saving model to model.h5
# Epoch 23/200
# 47/47 - 47s - loss: 0.8272 - val_loss: 0.8348
#
# Epoch 00023: val_loss improved from 0.83961 to 0.83478, saving model to model.h5
# Epoch 24/200
# 47/47 - 47s - loss: 0.8247 - val_loss: 0.8309
#
# Epoch 00024: val_loss improved from 0.83478 to 0.83092, saving model to model.h5
# Epoch 25/200
# 47/47 - 47s - loss: 0.8202 - val_loss: 0.8309
#
# Epoch 00025: val_loss did not improve from 0.83092
# Epoch 26/200
# 47/47 - 47s - loss: 0.8175 - val_loss: 0.8247
#
# Epoch 00026: val_loss improved from 0.83092 to 0.82467, saving model to model.h5
# Epoch 27/200
# 47/47 - 47s - loss: 0.8131 - val_loss: 0.8204
#
# Epoch 00027: val_loss improved from 0.82467 to 0.82036, saving model to model.h5
# Epoch 28/200
# 47/47 - 47s - loss: 0.8080 - val_loss: 0.8168
#
# Epoch 00028: val_loss improved from 0.82036 to 0.81675, saving model to model.h5
# Epoch 29/200
# 47/47 - 47s - loss: 0.8051 - val_loss: 0.8248
#
# Epoch 00029: val_loss did not improve from 0.81675
# Epoch 30/200
# 47/47 - 47s - loss: 0.8028 - val_loss: 0.8134
#
# Epoch 00030: val_loss improved from 0.81675 to 0.81336, saving model to model.h5
# Epoch 31/200
# 47/47 - 47s - loss: 0.7979 - val_loss: 0.8066
#
# Epoch 00031: val_loss improved from 0.81336 to 0.80660, saving model to model.h5
# Epoch 32/200
# 47/47 - 47s - loss: 0.7913 - val_loss: 0.8046
#
# Epoch 00032: val_loss improved from 0.80660 to 0.80462, saving model to model.h5
# Epoch 33/200
# 47/47 - 47s - loss: 0.7862 - val_loss: 0.7984
#
# Epoch 00033: val_loss improved from 0.80462 to 0.79839, saving model to model.h5
# Epoch 34/200
# 47/47 - 48s - loss: 0.7797 - val_loss: 0.7892
#
# Epoch 00034: val_loss improved from 0.79839 to 0.78924, saving model to model.h5
# Epoch 35/200
# 47/47 - 48s - loss: 0.7735 - val_loss: 0.7822
#
# Epoch 00035: val_loss improved from 0.78924 to 0.78223, saving model to model.h5
# Epoch 36/200
# 47/47 - 47s - loss: 0.7673 - val_loss: 0.7773
#
# Epoch 00036: val_loss improved from 0.78223 to 0.77732, saving model to model.h5
# Epoch 37/200
# 47/47 - 47s - loss: 0.7597 - val_loss: 0.7708
#
# Epoch 00037: val_loss improved from 0.77732 to 0.77084, saving model to model.h5
# Epoch 38/200
# 47/47 - 48s - loss: 0.7530 - val_loss: 0.7670
#
# Epoch 00038: val_loss improved from 0.77084 to 0.76704, saving model to model.h5
# Epoch 39/200
# 47/47 - 47s - loss: 0.7524 - val_loss: 0.7629
#
# Epoch 00039: val_loss improved from 0.76704 to 0.76288, saving model to model.h5
# Epoch 40/200
# 47/47 - 47s - loss: 0.7465 - val_loss: 0.7567
#
# Epoch 00040: val_loss improved from 0.76288 to 0.75666, saving model to model.h5
# Epoch 41/200
# 47/47 - 47s - loss: 0.7354 - val_loss: 0.7470
#
# Epoch 00041: val_loss improved from 0.75666 to 0.74704, saving model to model.h5
# Epoch 42/200
# 47/47 - 47s - loss: 0.7266 - val_loss: 0.7389
#
# Epoch 00042: val_loss improved from 0.74704 to 0.73895, saving model to model.h5
# Epoch 43/200
# 47/47 - 47s - loss: 0.7202 - val_loss: 0.7376
#
# Epoch 00043: val_loss improved from 0.73895 to 0.73765, saving model to model.h5
# Epoch 44/200
# 47/47 - 48s - loss: 0.7138 - val_loss: 0.7261
#
# Epoch 00044: val_loss improved from 0.73765 to 0.72615, saving model to model.h5
# Epoch 45/200
# 47/47 - 47s - loss: 0.7064 - val_loss: 0.7188
#
# Epoch 00045: val_loss improved from 0.72615 to 0.71883, saving model to model.h5
# Epoch 46/200
# 47/47 - 47s - loss: 0.6966 - val_loss: 0.7091
#
# Epoch 00046: val_loss improved from 0.71883 to 0.70907, saving model to model.h5
# Epoch 47/200
# 47/47 - 48s - loss: 0.6888 - val_loss: 0.7043
#
# Epoch 00047: val_loss improved from 0.70907 to 0.70432, saving model to model.h5
# Epoch 48/200
# 47/47 - 48s - loss: 0.6794 - val_loss: 0.6942
#
# Epoch 00048: val_loss improved from 0.70432 to 0.69424, saving model to model.h5
# Epoch 49/200
# 47/47 - 47s - loss: 0.6700 - val_loss: 0.6868
#
# Epoch 00049: val_loss improved from 0.69424 to 0.68677, saving model to model.h5
# Epoch 50/200
# 47/47 - 47s - loss: 0.6620 - val_loss: 0.6766
#
# Epoch 00050: val_loss improved from 0.68677 to 0.67663, saving model to model.h5
# Epoch 51/200
# 47/47 - 47s - loss: 0.6527 - val_loss: 0.6715
#
# Epoch 00051: val_loss improved from 0.67663 to 0.67147, saving model to model.h5
# Epoch 52/200
# 47/47 - 48s - loss: 0.6456 - val_loss: 0.6607
#
# Epoch 00052: val_loss improved from 0.67147 to 0.66065, saving model to model.h5
# Epoch 53/200
# 47/47 - 48s - loss: 0.6358 - val_loss: 0.6553
#
# Epoch 00053: val_loss improved from 0.66065 to 0.65534, saving model to model.h5
# Epoch 54/200
# 47/47 - 48s - loss: 0.6267 - val_loss: 0.6453
#
# Epoch 00054: val_loss improved from 0.65534 to 0.64527, saving model to model.h5
# Epoch 55/200
# 47/47 - 47s - loss: 0.6156 - val_loss: 0.6325
#
# Epoch 00055: val_loss improved from 0.64527 to 0.63246, saving model to model.h5
# Epoch 56/200
# 47/47 - 47s - loss: 0.6064 - val_loss: 0.6241
#
# Epoch 00056: val_loss improved from 0.63246 to 0.62415, saving model to model.h5
# Epoch 57/200
# 47/47 - 48s - loss: 0.5941 - val_loss: 0.6117
#
# Epoch 00057: val_loss improved from 0.62415 to 0.61165, saving model to model.h5
# Epoch 58/200
# 47/47 - 47s - loss: 0.5838 - val_loss: 0.6110
#
# Epoch 00058: val_loss improved from 0.61165 to 0.61099, saving model to model.h5
# Epoch 59/200
# 47/47 - 47s - loss: 0.5756 - val_loss: 0.5975
#
# Epoch 00059: val_loss improved from 0.61099 to 0.59749, saving model to model.h5
# Epoch 60/200
# 47/47 - 47s - loss: 0.5665 - val_loss: 0.5893
#
# Epoch 00060: val_loss improved from 0.59749 to 0.58930, saving model to model.h5
# Epoch 61/200
# 47/47 - 47s - loss: 0.5565 - val_loss: 0.5815
#
# Epoch 00061: val_loss improved from 0.58930 to 0.58147, saving model to model.h5
# Epoch 62/200
# 47/47 - 47s - loss: 0.5484 - val_loss: 0.5672
#
# Epoch 00062: val_loss improved from 0.58147 to 0.56723, saving model to model.h5
# Epoch 63/200
# 47/47 - 47s - loss: 0.5369 - val_loss: 0.5586
#
# Epoch 00063: val_loss improved from 0.56723 to 0.55859, saving model to model.h5
# Epoch 64/200
# 47/47 - 47s - loss: 0.5263 - val_loss: 0.5495
#
# Epoch 00064: val_loss improved from 0.55859 to 0.54952, saving model to model.h5
# Epoch 65/200
# 47/47 - 47s - loss: 0.5196 - val_loss: 0.5474
#
# Epoch 00065: val_loss improved from 0.54952 to 0.54742, saving model to model.h5
# Epoch 66/200
# 47/47 - 47s - loss: 0.5117 - val_loss: 0.5336
#
# Epoch 00066: val_loss improved from 0.54742 to 0.53356, saving model to model.h5
# Epoch 67/200
# 47/47 - 48s - loss: 0.5000 - val_loss: 0.5240
#
# Epoch 00067: val_loss improved from 0.53356 to 0.52401, saving model to model.h5
# Epoch 68/200
# 47/47 - 47s - loss: 0.4892 - val_loss: 0.5135
#
# Epoch 00068: val_loss improved from 0.52401 to 0.51347, saving model to model.h5
# Epoch 69/200
# 47/47 - 47s - loss: 0.4775 - val_loss: 0.5039
#
# Epoch 00069: val_loss improved from 0.51347 to 0.50388, saving model to model.h5
# Epoch 70/200
# 47/47 - 47s - loss: 0.4680 - val_loss: 0.5000
#
# Epoch 00070: val_loss improved from 0.50388 to 0.50004, saving model to model.h5
# Epoch 71/200
# 47/47 - 47s - loss: 0.4591 - val_loss: 0.4875
#
# Epoch 00071: val_loss improved from 0.50004 to 0.48747, saving model to model.h5
# Epoch 72/200
# 47/47 - 47s - loss: 0.4484 - val_loss: 0.4781
#
# Epoch 00072: val_loss improved from 0.48747 to 0.47813, saving model to model.h5
# Epoch 73/200
# 47/47 - 47s - loss: 0.4386 - val_loss: 0.4685
#
# Epoch 00073: val_loss improved from 0.47813 to 0.46850, saving model to model.h5
# Epoch 74/200
# 47/47 - 47s - loss: 0.4286 - val_loss: 0.4592
#
# Epoch 00074: val_loss improved from 0.46850 to 0.45922, saving model to model.h5
# Epoch 75/200
# 47/47 - 47s - loss: 0.4202 - val_loss: 0.4520
#
# Epoch 00075: val_loss improved from 0.45922 to 0.45196, saving model to model.h5
# Epoch 76/200
# 47/47 - 47s - loss: 0.4110 - val_loss: 0.4454
#
# Epoch 00076: val_loss improved from 0.45196 to 0.44544, saving model to model.h5
# Epoch 77/200
# 47/47 - 47s - loss: 0.4026 - val_loss: 0.4379
#
# Epoch 00077: val_loss improved from 0.44544 to 0.43789, saving model to model.h5
# Epoch 78/200
# 47/47 - 47s - loss: 0.3940 - val_loss: 0.4298
#
# Epoch 00078: val_loss improved from 0.43789 to 0.42981, saving model to model.h5
# Epoch 79/200
# 47/47 - 47s - loss: 0.3841 - val_loss: 0.4224
#
# Epoch 00079: val_loss improved from 0.42981 to 0.42239, saving model to model.h5
# Epoch 80/200
# 47/47 - 47s - loss: 0.3753 - val_loss: 0.4110
#
# Epoch 00080: val_loss improved from 0.42239 to 0.41104, saving model to model.h5
# Epoch 81/200
# 47/47 - 47s - loss: 0.3667 - val_loss: 0.4055
#
# Epoch 00081: val_loss improved from 0.41104 to 0.40549, saving model to model.h5
# Epoch 82/200
# 47/47 - 47s - loss: 0.3618 - val_loss: 0.4034
#
# Epoch 00082: val_loss improved from 0.40549 to 0.40344, saving model to model.h5
# Epoch 83/200
# 47/47 - 47s - loss: 0.3553 - val_loss: 0.3913
#
# Epoch 00083: val_loss improved from 0.40344 to 0.39126, saving model to model.h5
# Epoch 84/200
# 47/47 - 47s - loss: 0.3469 - val_loss: 0.3909
#
# Epoch 00084: val_loss improved from 0.39126 to 0.39087, saving model to model.h5
# Epoch 85/200
# 47/47 - 47s - loss: 0.3385 - val_loss: 0.3781
#
# Epoch 00085: val_loss improved from 0.39087 to 0.37806, saving model to model.h5
# Epoch 86/200
# 47/47 - 47s - loss: 0.3279 - val_loss: 0.3712
#
# Epoch 00086: val_loss improved from 0.37806 to 0.37116, saving model to model.h5
# Epoch 87/200
# 47/47 - 48s - loss: 0.3205 - val_loss: 0.3672
#
# Epoch 00087: val_loss improved from 0.37116 to 0.36716, saving model to model.h5
# Epoch 88/200
# 47/47 - 48s - loss: 0.3185 - val_loss: 0.3621
#
# Epoch 00088: val_loss improved from 0.36716 to 0.36213, saving model to model.h5
# Epoch 89/200
# 47/47 - 48s - loss: 0.3095 - val_loss: 0.3514
#
# Epoch 00089: val_loss improved from 0.36213 to 0.35143, saving model to model.h5
# Epoch 90/200
# 47/47 - 47s - loss: 0.2986 - val_loss: 0.3460
#
# Epoch 00090: val_loss improved from 0.35143 to 0.34598, saving model to model.h5
# Epoch 91/200
# 47/47 - 47s - loss: 0.2911 - val_loss: 0.3383
#
# Epoch 00091: val_loss improved from 0.34598 to 0.33829, saving model to model.h5
# Epoch 92/200

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-LowSaxon-both.pkl')
train = load_clean_sentences('english-LowSaxon-train.pkl')
test = load_clean_sentences('english-LowSaxon-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[Wo kummt dat dat du so veel von japaansche Geschicht afkennst], target=[How is it that you know so much about Japanese history], predicted=[how long you you that what that that is japanese]
# src=[Een Drüppen von dat Gift reckt üm 160 Lüüd ümtobringen], target=[One drop of the poison is enough to kill 160 people], predicted=[the drop of of poison is enough kill kill 160]
# src=[Wo lang hebbt wi bruukt dit Book to översetten], target=[How long did it take us to translate this book], predicted=[how will will will to to to translate this book]
# src=[Ik bün gornich mööd], target=[Im not at all tired], predicted=[im not not tired tired]
# src=[He keem dör dat Finster rin], target=[He entered through the window], predicted=[he entered through the window]
# src=[Ik gah trügg], target=[Im going back], predicted=[im going back]
# src=[Treck dien Schoh ut], target=[Take off your shoes], predicted=[take your your shoes]
# src=[Ik will nich arbeiden], target=[I dont want to work], predicted=[i dont want to work]
# src=[Ik weer de Hitt wennt], target=[I was used to the heat], predicted=[i was used to the heat]
# src=[Se hett em jümmer een Maal in ’t Johr besöcht], target=[She visited him once a year], predicted=[she visited him once a year]
# BLEU-1: 0.590473
# BLEU-2: 0.477257
# BLEU-3: 0.412979
# BLEU-4: 0.280018
# test
# src=[Du hest keen Smack], target=[You have no taste], predicted=[you have have taste]
# src=[Wat is dien Moderspraak], target=[Whats your native language], predicted=[whats your native language]
# src=[Dat rode Kleed lett good an ehr], target=[That red dress looks good on her], predicted=[the dress looks looks in in her]
# src=[Ik harr geern en Bruus], target=[Id like a soda], predicted=[id like a soda]
# src=[Dit Foto is in Nara opnahmen], target=[This photo was taken in Nara], predicted=[the photo was taken in nara]
# src=[Mi dücht wi bruukt Hülp], target=[I think we need help], predicted=[i dont we help help]
# src=[Dat is to düür], target=[Its too expensive], predicted=[its is expensive]
# src=[He is dat swarte Schaap in ’e Famielje], target=[Hes the black sheep of the family], predicted=[hes is the sheep of the family]
# src=[Disse CD köst teihn Dollar], target=[This CD costs ten dollars], predicted=[this cd costs ten dollars]
# src=[Se weer doodbleven bevör ik ankamen bün], target=[She had died before I arrived], predicted=[she saw them before she blonde]
# BLEU-1: 0.564395
# BLEU-2: 0.452246
# BLEU-3: 0.391770
# BLEU-4: 0.263699

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-LowSaxon-both.pkl')
train = load_clean_sentences('english-LowSaxon-train.pkl')
test = load_clean_sentences('english-LowSaxon-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[He hett twee Böker utlehnt], target=[He borrowed two books], predicted=[he borrowed two books]
# src=[Washington sien Armee hett Trenton innahmen], target=[Washingtons army has captured Trenton], predicted=[washingtons army has captured trenton]
# src=[Ik bün na ’n Markt gahn], target=[I went to the market], predicted=[i went to the market]
# src=[Woveel köst en Kamer], target=[How much is a room], predicted=[how much is a room]
# src=[De Ammel weer vull mit Water], target=[The bucket was full of water], predicted=[the bucket was full of water]
# src=[Mien Hund deit faken so as wenn he slöppt], target=[My dog often pretends to be asleep], predicted=[my dog often pretends to be asleep]
# src=[Dat is nich mien Schuld], target=[Thats not my fault], predicted=[its not my fault]
# src=[Ik bün gornich mööd], target=[Im not at all tired], predicted=[im not at all tired]
# src=[Do dien Mütz op], target=[Put on your cap], predicted=[put on your cap]
# src=[Indien is 1947 von Grootbritannien unafhängig worrn], target=[India gained independence from Britain in 1947], predicted=[india gained independence from britain in 1947]
# BLEU-1: 0.785786
# BLEU-2: 0.753492
# BLEU-3: 0.740175
# BLEU-4: 0.668968
# test
# src=[Is se weg], target=[Is she gone], predicted=[is she gone]
# src=[Mien leevsten Sport is Football], target=[My favorite sport is soccer], predicted=[my favorite sport is soccer]
# src=[Ik heff keen Hoor op ’n Kopp], target=[I have no hair on my head], predicted=[i have no hair on my head]
# src=[Wo kennst du mien Naam von], target=[How do you know my name], predicted=[how do you know my name]
# src=[Mien Rügg deit jümmer noch weh], target=[My back still hurts], predicted=[my back still hurts]
# src=[Woneem is de Toilett], target=[Wheres the restroom], predicted=[wheres the restroom]
# src=[Dat Peerd leeg op ’t Stroh], target=[The horse was lying on the straw], predicted=[the horse was lying on the straw]
# src=[He hett mi anschülligt en Löögner to wesen], target=[He accused me of being a liar], predicted=[he accused me of being a liar]
# src=[Güstern heff ik en Book köfft], target=[Yesterday I bought a book], predicted=[yesterday i bought a book]
# src=[Se weren all so mööd dat se anners nix as jappen kunnen], target=[They were all so tired that they could do nothing but yawn], predicted=[they were all so tired that they could do nothing but yawn]
# BLEU-1: 0.749318
# BLEU-2: 0.713802
# BLEU-3: 0.702898
# BLEU-4: 0.630855
